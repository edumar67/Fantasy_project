# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib.ticker import PercentFormatter

df_desordenado = pd.read_csv('../data/fantasy_data.csv')
df_desordenado = df_desordenado.drop(["PPGTarget_half-ppr","PointsTarget_half-ppr","Player","Key"], axis=1)

# %%
df_ordenado = df_desordenado.sort_values('Year')
df_ordenado = df_ordenado[~df_ordenado['Year'].between(1970, 1999)]
df_ordenado
# Out:
#         Tm Pos  Age   G  GS  Pass_Cmp  Pass_Att  Pass_Yds  Pass_TD  Pass_Int  \
# 12838  BAL  WR   30  15  13         0         0         0        0         0
# 9035   SFO  QB   30  16  16       355       561      4278       31        10
# 25833  WAS  WR   23   4   0         0         0         0        0         0
# 23353  WAS  TE   25  15   6         0         0         0        0         0
# 5027   DEN  RB   22   9   0         0         0         0        0         0
# ...    ...  ..  ...  ..  ..       ...       ...       ...      ...       ...
# 16849  TEN  WR   27   1   0         0         0         0        0         0
# 16766  TEN  TE   25   5   2         0         0         0        0         0
# 16736  LVR  WR   24   7   1         0         0         0        0         0
# 17679  CIN  TE   25   2   0         0         0         0        0         0
# 29368  DET  TE   28  12   1         0         0         0        0         0
#
# ...

# %%
df_ordenado["Year"]
# Out:
# 12838    2000
# 9035     2000
# 25833    2000
# 23353    2000
# 5027     2000
#          ...
# 16849    2024
# 16766    2024
# 16736    2024
# 17679    2024
# 29368    2024
# Name: Year, Length: 14893, dtype: int64

# %%
df_ordenado["games_played_pct"] = df_ordenado["games_played_pct"]
df_ordenado["games_played_pct"].value_counts()
# Out:
# games_played_pct
# 1.000000    4319
# 0.937500    1212
# 0.875000     904
# 0.812500     682
# 0.062500     673
# 0.750000     559
# 0.125000     549
# 0.187500     484
# 0.687500     466
# 0.625000     464
# 0.500000     452
# 0.312500     429
# 0.250000     428
# 0.437500     415
# 0.375000     409
# 0.562500     384
# 0.941176     268
# 0.882353     193
# 0.058824     175
# 0.117647     141
# 0.823529     136
# 0.764706     132
# 0.176471     129
# 0.705882     124
# 0.647059      99
# 0.529412      99
# 0.470588      98
# 0.294118      96
# 0.588235      93
# 0.352941      90
# 0.235294      90
# 0.411765      84
# 0.000000      13
# 1.062500       3
# 1.058824       1
# Name: count, dtype: int64

# %%
df_ordenado[df_ordenado["games_played_pct"] == 1.06250]
# Out:
#         Tm Pos  Age   G  GS  Pass_Cmp  Pass_Att  Pass_Yds  Pass_TD  Pass_Int  \
# 22593  2TM  WR   28  17   0         0         0         0        0         0
# 21925  2TM  WR   42  17  14         0         0         0        0         0
# 22949  2TM  WR   32  17  16         1         1        35        1         0
#
#        ...  PPG_half-ppr  PPT_half-ppr  PointsOvrRank_half-ppr  \
# 22593  ...      0.000000       0.00000                     514
# 21925  ...      4.464706       2.53000                     162
# 22949  ...      9.135294       2.31791                      92
#
#        PointsPosRank_half-ppr  PPGOvrRank_half-ppr  PPGPosRank_half-ppr  \
# 22593                     170                  514                  170
# 21925                      68                  224                   82
# 22949                      33                  136                   46
#
#        PPTOvrRank_half-ppr  PPTPosRank_half-ppr  Points_VORP_half-ppr  \
# ...

# %%
def resumen_nulos(df):
    nulos = df.isnull().sum()
    porcentaje = (nulos / len(df)) * 100
    resumen = pd.DataFrame({
        'Columna': df.columns,
        'Nulos': nulos.values,
        'Porcentaje_Nulos': porcentaje.values
    })
    return resumen.sort_values('Nulos', ascending=False)

# usamos nuestra función
print(resumen_nulos(df_ordenado))

df_ordenado = df_ordenado.drop(['PPGTarget_half-ppr','PointsTarget_half-ppr'], axis=1)

print(resumen_nulos(df_ordenado))
# Out:
#               Columna  Nulos  Porcentaje_Nulos
# 0                  Tm      0               0.0
# 46       Fmb_per_game      0               0.0
# 33         Rec_Catch%      0               0.0
# 34  Pass_Cmp_per_game      0               0.0
# 35  Pass_Att_per_game      0               0.0
# ..                ...    ...               ...
# 25          num_games      0               0.0
# 26   games_played_pct      0               0.0
# 27  games_started_pct      0               0.0
# 28            ProBowl      0               0.0
# 61  PPG_VORP_half-ppr      0               0.0
#
# [62 rows x 3 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[118], line 14
#      11 # usamos nuestra función
#      12 print(resumen_nulos(df_ordenado))
# ---> 14 df_ordenado = df_ordenado.drop(['PPGTarget_half-ppr','PointsTarget_half-ppr'], axis=1)
# ...
